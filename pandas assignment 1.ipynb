# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv(r"C:\Users\DELL\Downloads\cleaned_all_phones.csv")

# %%
x
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
#1 How many unique  mobile brands are there in the data provided
x1=x["brand"].unique()

# %%
x1
# Out:
# array(['Huawei', 'LG', 'Xiaomi', 'Sony', 'Oppo', 'Samsung', 'Lenovo',
#        'Apple', 'Google', 'Honor', 'Realme', 'OnePlus', 'Vivo'],
#       dtype=object)

# %%
len(x1)
# Out:
# 13

# %%
#2 What is the average ram size of all the collected data
x1=x["ram(GB)"].mean()

# %%
x1
# Out:
# 6.6838624338624335

# %%
#3 Which phone is having the maximum and minimum battery capacity

# %%
x.loc[x['battery'].idxmax()]
# Out:
# phone_name                   V6
# brand                     Honor
# os                   Android 10
# inches                     10.4
# resolution            1200x2000
# battery                    7250
# battery_type              Li-Po
# ram(GB)                       8
# announcement_date    2020-05-19
# weight(g)                 480.0
# storage(GB)                  64
# video_720p                False
# video_1080p                True
# video_4K                  False
# video_8K                  False
# video_30fps                True
# video_60fps               False
# video_120fps              False
# video_240fps              False
# video_480fps              False
# video_960fps              False
# price(USD)                280.0
# Name: 573, dtype: object

# %%
x.loc[x['battery'].idxmin()]
# Out:
# phone_name             iPhone 8
# brand                     Apple
# os                       iOS 11
# inches                      4.7
# resolution             750x1334
# battery                    1821
# battery_type             Li-Ion
# ram(GB)                       2
# announcement_date    2017-09-12
# weight(g)                 148.0
# storage(GB)                  64
# video_720p                 True
# video_1080p                True
# video_4K                   True
# video_8K                  False
# video_30fps                True
# video_60fps                True
# video_120fps               True
# video_240fps               True
# video_480fps              False
# video_960fps              False
# price(USD)                210.0
# Name: 62, dtype: object

# %%
#4 What is the maximum battery capacity provided by Huawei Company

x["battery"].max().loc["Huawei"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 #4 What is the maximum battery capacity provided by Huawei Company
# ----> 3 x["battery"].max().loc["Huawei"]
#
# AttributeError: 'int' object has no attribute 'loc'

# %%
# 5 Which Phone brand is providing the highest and lowest ram

x1=(x["ram(GB)"]==x["ram(GB)"].max())

# %%
x.loc[x1]["brand"]
# Out:
# 1505     Xiaomi
# 1506    OnePlus
# 1510     Realme
# Name: brand, dtype: object

# %%
x2=(x["ram(GB)"]==x["ram(GB)"].min())

# %%
x.loc[x2]["brand"]
# Out:
# 27      Huawei
# 28     Samsung
# 69     Samsung
# 133     Huawei
# 182    Samsung
# 230    Samsung
# 236     Huawei
# 244     Xiaomi
# 304    Samsung
# 363         LG
# 550    Samsung
# Name: brand, dtype: object

# %%
# 6 How many phones has android 7.0 as there operating system

# %%
x2=x.loc[x["os"]=="Android 7.0",["phone_name","os"]]

# %%
x2
# Out:
#             phone_name           os
# 1             K20 plus  Android 7.0
# 2       P8 Lite (2017)  Android 7.0
# 4                  P10  Android 7.0
# 5           Xperia XA1  Android 7.0
# 6             P10 Lite  Android 7.0
# 7             P10 Plus  Android 7.0
# 8     Xperia XA1 Ultra  Android 7.0
# 9             X power2  Android 7.0
# 13           Xperia L1  Android 7.0
# 16     Galaxy Xcover 4  Android 7.0
# 18          Galaxy S8+  Android 7.0
# 21             Harmony  Android 7.0
# 24                  Y7  Android 7.0
# 25         nova 2 plus  Android 7.0
# 26              nova 2  Android 7.0
# 31        Stylo 3 Plus  Android 7.0
# 33           X venture  Android 7.0
# 37       Galaxy J7 Max  Android 7.0
# 38    Galaxy J7 (2017)  Android 7.0
# 39       Galaxy J7 Pro  Android 7.0
# 40    Galaxy J5 (2017)  Android 7.0
# 41            Y7 Prime  Android 7.0
# 43           Q8 (2017)  Android 7.0
# 47        P9 lite mini  Android 7.0
# 49    Galaxy S8 Active  Android 7.0
# ...

# %%
# 7 Which Phone is the oldest 

x1=x.loc[x["announcement_date"]==x1["announcement_date"].min()]

# %%
x1["phone_name"]
# Out:
# 1    K20 plus
# Name: phone_name, dtype: object

# %%
# 8 Which brand produced maximum number of phone in the given data
x1=x["brand"].min()
x.loc[x["brand"]==x1,["phone_name","brand"]].count()
# Out:
# phone_name    22
# brand         22
# dtype: int64

# %%
#9 Give the count of phones supporting 4k video,8k video,2k video

print(len(x.loc[x["video_4K"]==True,["brand","phone_name"]]))
x.loc[x["video_4K"]==True,["brand","phone_name"]]
# Out:
# 801
#         brand         phone_name
# 4      Huawei                P10
# 7      Huawei           P10 Plus
# 11       Sony         Xperia XZs
# 12       Sony  Xperia XZ Premium
# 15       Oppo            F3 Plus
# ...       ...                ...
# 1505   Xiaomi    Redmi K60 Ultra
# 1506  OnePlus          Ace 2 Pro
# 1509   Realme                GT5
# 1510   Realme           GT5 240W
# 1511     Vivo   vivo iQOO Z7 Pro
#
# [801 rows x 2 columns]

# %%
print(len(x.loc[x["video_8K"]==True,["brand","phone_name"]]))
x.loc[x["video_8K"]==True,["brand","phone_name"]]
# Out:
# 86
#         brand           phone_name
# 466   Samsung        Galaxy S20 5G
# 467   Samsung       Galaxy S20+ 5G
# 468   Samsung     Galaxy S20 Ultra
# 470   Samsung  Galaxy S20 Ultra 5G
# 471   Samsung          Galaxy S20+
# ...       ...                  ...
# 1447     Vivo       vivo iQOO Neo8
# 1476     Vivo        vivo iQOO 11S
# 1497  Samsung       Galaxy Z Fold5
# 1504   Xiaomi           Mix Fold 3
# 1505   Xiaomi      Redmi K60 Ultra
#
# [86 rows x 2 columns]

# %%
#10 How many phones supports Li-Po and Li-ion Battery
x1=x.loc[x["battery_type"]=="Li-Po",["phone_name"]].count()

# %%
x1
# Out:
# phone_name    1242
# dtype: int64

# %%
x2=x.loc[x["battery_type"]=="Li-Ion",["phone_name"]].count()

# %%
x2
# Out:
# phone_name    270
# dtype: int64

# %%
# 11 How many sony phones supports 720x1280 resolution

# %%
# 12 Print a pivot table for finding the average weights ,total weights,based on brand and battery type

pd.pivot_table(x,index="brand",columns="battery_type",values=["weight(g)"],aggfunc=["mean"])
# Out:
#                     mean
#                weight(g)
# battery_type      Li-Ion       Li-Po
# brand
# Apple         186.227273         NaN
# Google        190.666667  176.923077
# Honor         165.333333  190.611570
# Huawei        158.354839  187.556604
# LG            154.851852  183.812500
# Lenovo        190.142857  218.586207
# OnePlus              NaN  191.553191
# Oppo          157.833333  183.174603
# Realme        166.833333  189.688742
# Samsung       178.531250  196.727273
# Sony          177.333333  178.769231
# Vivo                 NaN  190.232143
# Xiaomi        179.294118  195.906883
